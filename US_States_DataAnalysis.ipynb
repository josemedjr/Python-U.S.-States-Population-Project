# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\14703\OneDrive\Personal_Projects\USPopulation.csv")

# %%
df
# Out:
#              State/Territory   2020 pop.   2010 pop.   2000 pop.  \
# 0              Massachusetts   7,029,917   6,547,629   6,349,097
# 1                Connecticut   3,605,944   3,574,097   3,405,565
# 2              New Hampshire   1,377,529   1,316,470   1,235,786
# 3                      Maine   1,362,359   1,328,361   1,274,923
# 4               Rhode Island   1,097,379   1,052,567   1,048,319
# 5                    Vermont     643,077     625,741     608,827
# 6                   New York  20,201,249  19,378,102  18,976,457
# 7               Pennsylvania  13,002,700  12,702,379  12,281,054
# 8                 New Jersey   9,288,994   8,791,894   8,414,350
# 9                    Florida  21,538,187  18,801,310  15,982,378
# 10                   Georgia  10,711,908   9,687,653   8,186,453
# 11            North Carolina  10,439,388   9,535,483   8,049,313
# 12                  Virginia   8,631,393   8,001,024   7,078,515
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   State/Territory  56 non-null     object
#  1   2020 pop.        56 non-null     object
#  2   2010 pop.        56 non-null     object
#  3   2000 pop.        56 non-null     object
#  4   2010–2020change  56 non-null     object
#  5   Region           56 non-null     object
# dtypes: object(6)
# memory usage: 2.8+ KB

# %%
df['2020 pop.'] = df['2020 pop.'].str.replace(',', '').astype(float)
df['2010 pop.'] = df['2010 pop.'].str.replace(',', '').astype(float)
df['2000 pop.'] = df['2000 pop.'].str.replace(',', '').astype(float)

# %%
df
# Out:
#              State/Territory   2020 pop.   2010 pop.   2000 pop.  \
# 0              Massachusetts   7029917.0   6547629.0   6349097.0
# 1                Connecticut   3605944.0   3574097.0   3405565.0
# 2              New Hampshire   1377529.0   1316470.0   1235786.0
# 3                      Maine   1362359.0   1328361.0   1274923.0
# 4               Rhode Island   1097379.0   1052567.0   1048319.0
# 5                    Vermont    643077.0    625741.0    608827.0
# 6                   New York  20201249.0  19378102.0  18976457.0
# 7               Pennsylvania  13002700.0  12702379.0  12281054.0
# 8                 New Jersey   9288994.0   8791894.0   8414350.0
# 9                    Florida  21538187.0  18801310.0  15982378.0
# 10                   Georgia  10711908.0   9687653.0   8186453.0
# 11            North Carolina  10439388.0   9535483.0   8049313.0
# 12                  Virginia   8631393.0   8001024.0   7078515.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   State/Territory  56 non-null     object
#  1   2020 pop.        56 non-null     float64
#  2   2010 pop.        56 non-null     float64
#  3   2000 pop.        56 non-null     float64
#  4   2010–2020change  56 non-null     object
#  5   Region           56 non-null     object
# dtypes: float64(3), object(3)
# memory usage: 2.8+ KB

# %%
df.groupby('Region').mean(numeric_only = True)
# Out:
#                     2020 pop.     2010 pop.     2000 pop.
# Region
# Islands          7.247790e+05  8.201908e+05  8.397078e+05
# Mid-Atlantic     1.416431e+07  1.362412e+07  1.322395e+07
# Mid-West         5.748788e+06  5.577250e+06  5.366065e+06
# New England      2.519368e+06  2.407478e+06  2.320420e+06
# Pacific          1.073388e+07  9.976020e+06  9.005127e+06
# Rocky Mountains  3.114894e+06  2.758181e+06  2.271537e+06
# South            7.522047e+06  6.847338e+06  6.058458e+06
# South-Atlantic   7.343304e+06  6.641893e+06  5.752129e+06

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df
# Out:
#              State/Territory   2020 pop.   2010 pop.   2000 pop.  \
# 0              Massachusetts  7029917.00  6547629.00  6349097.00
# 1                Connecticut  3605944.00  3574097.00  3405565.00
# 2              New Hampshire  1377529.00  1316470.00  1235786.00
# 3                      Maine  1362359.00  1328361.00  1274923.00
# 4               Rhode Island  1097379.00  1052567.00  1048319.00
# 5                    Vermont   643077.00   625741.00   608827.00
# 6                   New York 20201249.00 19378102.00 18976457.00
# 7               Pennsylvania 13002700.00 12702379.00 12281054.00
# 8                 New Jersey  9288994.00  8791894.00  8414350.00
# 9                    Florida 21538187.00 18801310.00 15982378.00
# 10                   Georgia 10711908.00  9687653.00  8186453.00
# 11            North Carolina 10439388.00  9535483.00  8049313.00
# 12                  Virginia  8631393.00  8001024.00  7078515.00
# ...

# %%
df2 = df.groupby('Region').mean(numeric_only = True).sort_values(by = '2020 pop.', ascending = False)

# %%
df
# Out:
#              State/Territory   2020 pop.   2010 pop.   2000 pop.  \
# 0              Massachusetts  7029917.00  6547629.00  6349097.00
# 1                Connecticut  3605944.00  3574097.00  3405565.00
# 2              New Hampshire  1377529.00  1316470.00  1235786.00
# 3                      Maine  1362359.00  1328361.00  1274923.00
# 4               Rhode Island  1097379.00  1052567.00  1048319.00
# 5                    Vermont   643077.00   625741.00   608827.00
# 6                   New York 20201249.00 19378102.00 18976457.00
# 7               Pennsylvania 13002700.00 12702379.00 12281054.00
# 8                 New Jersey  9288994.00  8791894.00  8414350.00
# 9                    Florida 21538187.00 18801310.00 15982378.00
# 10                   Georgia 10711908.00  9687653.00  8186453.00
# 11            North Carolina 10439388.00  9535483.00  8049313.00
# 12                  Virginia  8631393.00  8001024.00  7078515.00
# ...

# %%
df2
# Out:
#                   2020 pop.   2010 pop.   2000 pop.
# Region
# Mid-Atlantic    14164314.33 13624125.00 13223953.67
# Pacific         10733884.40  9976020.40  9005127.40
# South            7522046.62  6847338.38  6058457.50
# South-Atlantic   7343303.78  6641893.00  5752128.89
# Mid-West         5748787.83  5577250.08  5366064.67
# Rocky Mountains  3114893.75  2758181.38  2271536.88
# New England      2519367.50  2407477.50  2320419.50
# Islands           724779.00   820190.80   839707.80

# %%
df2.plot()
# Out:
# <Axes: xlabel='Region'>

# %%
df3= df2.transpose()

# %%
df3.plot()
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['State/Territory', '2020 pop.', '2010 pop.', '2000 pop.',
#        '2010–2020change', 'Region'],
#       dtype='object')

# %%
df4 = df.groupby('Region')[['2000 pop.', '2010 pop.', '2020 pop.']]. mean(numeric_only = True).sort_values(by = '2020 pop.', ascending = False)

# %%
df4
# Out:
#                   2000 pop.   2010 pop.   2020 pop.
# Region
# Mid-Atlantic    13223953.67 13624125.00 14164314.33
# Pacific          9005127.40  9976020.40 10733884.40
# South            6058457.50  6847338.38  7522046.62
# South-Atlantic   5752128.89  6641893.00  7343303.78
# Mid-West         5366064.67  5577250.08  5748787.83
# Rocky Mountains  2271536.88  2758181.38  3114893.75
# New England      2320419.50  2407477.50  2519367.50
# Islands           839707.80   820190.80   724779.00

# %%
df5 = df4.transpose()

# %%
df5
# Out:
# Region     Mid-Atlantic     Pacific      South  South-Atlantic   Mid-West  \
# 2000 pop.   13223953.67  9005127.40 6058457.50      5752128.89 5366064.67
# 2010 pop.   13624125.00  9976020.40 6847338.38      6641893.00 5577250.08
# 2020 pop.   14164314.33 10733884.40 7522046.62      7343303.78 5748787.83
#
# Region     Rocky Mountains  New England   Islands
# 2000 pop.       2271536.88   2320419.50 839707.80
# 2010 pop.       2758181.38   2407477.50 820190.80
# 2020 pop.       3114893.75   2519367.50 724779.00

# %%
df5.plot()
# Out:
# <Axes: >

# %%
df
# Out:
#              State/Territory   2020 pop.   2010 pop.   2000 pop.  \
# 0              Massachusetts  7029917.00  6547629.00  6349097.00
# 1                Connecticut  3605944.00  3574097.00  3405565.00
# 2              New Hampshire  1377529.00  1316470.00  1235786.00
# 3                      Maine  1362359.00  1328361.00  1274923.00
# 4               Rhode Island  1097379.00  1052567.00  1048319.00
# 5                    Vermont   643077.00   625741.00   608827.00
# 6                   New York 20201249.00 19378102.00 18976457.00
# 7               Pennsylvania 13002700.00 12702379.00 12281054.00
# 8                 New Jersey  9288994.00  8791894.00  8414350.00
# 9                    Florida 21538187.00 18801310.00 15982378.00
# 10                   Georgia 10711908.00  9687653.00  8186453.00
# 11            North Carolina 10439388.00  9535483.00  8049313.00
# 12                  Virginia  8631393.00  8001024.00  7078515.00
# ...

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#         2020 pop.   2010 pop.   2000 pop.
# count       56.00       56.00       56.00
# mean   5983449.57  5586544.50  5100365.09
# std    7266323.43  6692771.79  6045959.01
# min      47329.00    53883.00    57291.00
# 25%    1373736.50  1325388.25  1229723.75
# 50%    3782648.50  3738570.00  3436026.50
# 75%    7060313.25  6499758.75  5940712.00
# max   39538223.00 37253956.00 33871648.00

# %%
df5
# Out:
# Region     Mid-Atlantic     Pacific      South  South-Atlantic   Mid-West  \
# 2000 pop.   13223953.67  9005127.40 6058457.50      5752128.89 5366064.67
# 2010 pop.   13624125.00  9976020.40 6847338.38      6641893.00 5577250.08
# 2020 pop.   14164314.33 10733884.40 7522046.62      7343303.78 5748787.83
#
# Region     Rocky Mountains  New England   Islands
# 2000 pop.       2271536.88   2320419.50 839707.80
# 2010 pop.       2758181.38   2407477.50 820190.80
# 2020 pop.       3114893.75   2519367.50 724779.00

# %%
df5.plot(kind = 'bar', stacked = 'True')
# Out:
# <Axes: >

# %%
df5['South'].plot(kind = 'bar', stacked = 'True')
# Out:
# <Axes: >

# %%
df5.plot.pie(y = 'Mid-Atlantic', figsize = (10,10))
# Out:
# <Axes: ylabel='Mid-Atlantic'>

# %%
df5['Islands'].plot(kind = 'bar', stacked = True)
# Out:
# <Axes: >

# %%
df
# Out:
#              State/Territory   2020 pop.   2010 pop.   2000 pop.  \
# 0              Massachusetts  7029917.00  6547629.00  6349097.00
# 1                Connecticut  3605944.00  3574097.00  3405565.00
# 2              New Hampshire  1377529.00  1316470.00  1235786.00
# 3                      Maine  1362359.00  1328361.00  1274923.00
# 4               Rhode Island  1097379.00  1052567.00  1048319.00
# 5                    Vermont   643077.00   625741.00   608827.00
# 6                   New York 20201249.00 19378102.00 18976457.00
# 7               Pennsylvania 13002700.00 12702379.00 12281054.00
# 8                 New Jersey  9288994.00  8791894.00  8414350.00
# 9                    Florida 21538187.00 18801310.00 15982378.00
# 10                   Georgia 10711908.00  9687653.00  8186453.00
# 11            North Carolina 10439388.00  9535483.00  8049313.00
# 12                  Virginia  8631393.00  8001024.00  7078515.00
# ...

# %%
NewEng = ['New England']
df[df['Region'].isin(NewEng)]
# Out:
#   State/Territory  2020 pop.  2010 pop.  2000 pop. 2010–2020change  \
# 0   Massachusetts 7029917.00 6547629.00 6349097.00            7.4%
# 1     Connecticut 3605944.00 3574097.00 3405565.00            0.9%
# 2   New Hampshire 1377529.00 1316470.00 1235786.00            4.6%
# 3           Maine 1362359.00 1328361.00 1274923.00            2.6%
# 4    Rhode Island 1097379.00 1052567.00 1048319.00            4.3%
# 5         Vermont  643077.00  625741.00  608827.00            2.8%
#
#         Region
# 0  New England
# 1  New England
# 2  New England
# 3  New England
# 4  New England
# 5  New England

# %%
df[df['State/Territory'].str.contains('New')]
# Out:
#    State/Territory   2020 pop.   2010 pop.   2000 pop. 2010–2020change  \
# 2    New Hampshire  1377529.00  1316470.00  1235786.00            4.6%
# 6         New York 20201249.00 19378102.00 18976457.00            4.2%
# 8       New Jersey  9288994.00  8791894.00  8414350.00            5.7%
# 42      New Mexico  2117522.00  2059179.00  1819046.00            2.8%
#
#              Region
# 2       New England
# 6      Mid-Atlantic
# 8      Mid-Atlantic
# 42  Rocky Mountains

# %%
df.set_index('State/Territory')
# Out:
#                            2020 pop.   2010 pop.   2000 pop. 2010–2020change  \
# State/Territory
# Massachusetts             7029917.00  6547629.00  6349097.00            7.4%
# Connecticut               3605944.00  3574097.00  3405565.00            0.9%
# New Hampshire             1377529.00  1316470.00  1235786.00            4.6%
# Maine                     1362359.00  1328361.00  1274923.00            2.6%
# Rhode Island              1097379.00  1052567.00  1048319.00            4.3%
# Vermont                    643077.00   625741.00   608827.00            2.8%
# New York                 20201249.00 19378102.00 18976457.00            4.2%
# Pennsylvania             13002700.00 12702379.00 12281054.00            2.4%
# New Jersey                9288994.00  8791894.00  8414350.00            5.7%
# Florida                  21538187.00 18801310.00 15982378.00           14.6%
# Georgia                  10711908.00  9687653.00  8186453.00           10.6%
# ...

# %%
df.filter(items = ['State/Territory', '2020 pop.', 'Region'])
# Out:
#              State/Territory   2020 pop.           Region
# 0              Massachusetts  7029917.00      New England
# 1                Connecticut  3605944.00      New England
# 2              New Hampshire  1377529.00      New England
# 3                      Maine  1362359.00      New England
# 4               Rhode Island  1097379.00      New England
# 5                    Vermont   643077.00      New England
# 6                   New York 20201249.00     Mid-Atlantic
# 7               Pennsylvania 13002700.00     Mid-Atlantic
# 8                 New Jersey  9288994.00     Mid-Atlantic
# 9                    Florida 21538187.00   South-Atlantic
# 10                   Georgia 10711908.00   South-Atlantic
# 11            North Carolina 10439388.00   South-Atlantic
# 12                  Virginia  8631393.00   South-Atlantic
# 13                  Maryland  6177224.00   South-Atlantic
# 14            South Carolina  5118425.00   South-Atlantic
# ...

# %%
df2['2020 pop.'].plot(kind= 'bar', stacked = True)
# Out:
# <Axes: xlabel='Region'>

# %%
df2
# Out:
#                   2020 pop.   2010 pop.   2000 pop.
# Region
# Mid-Atlantic    14164314.33 13624125.00 13223953.67
# Pacific         10733884.40  9976020.40  9005127.40
# South            7522046.62  6847338.38  6058457.50
# South-Atlantic   7343303.78  6641893.00  5752128.89
# Mid-West         5748787.83  5577250.08  5366064.67
# Rocky Mountains  3114893.75  2758181.38  2271536.88
# New England      2519367.50  2407477.50  2320419.50
# Islands           724779.00   820190.80   839707.80
